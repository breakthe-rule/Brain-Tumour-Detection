# %% [markdown]
# # Importing Libraries

# %%
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB2,EfficientNetB3,EfficientNetB5,InceptionResNetV2#,EfficientNetV2S
from tensorflow.keras.applications import VGG19,ResNet50
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import keras
import sklearn.metrics as metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
import time
from sklearn import metrics
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
DEVICE = "TPU" #or "GPU"

if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE != "TPU":
    print("Using default strategy for CPU and single GPU")
    strategy = tf.distribute.MirroredStrategy()

if DEVICE == "GPU":
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# connecting to TPU...
# Could not connect to TPU
# Using default strategy for CPU and single GPU
# Num GPUs Available:  2
# REPLICAS: 2

# %% [markdown]
# # Preparing data for training

# %%
#create labels
classes=[]
filename='../input/brain-tumor-classification-mri'
for sub_folder in os.listdir(os.path.join(filename,'Training')):
    classes.append(sub_folder)
print(classes)
# Out:
# ['no_tumor', 'pituitary_tumor', 'meningioma_tumor', 'glioma_tumor']

# %%
X_train = []
y_train = []
image_size = 160
for i in classes:
    path_train = os.path.join(filename,'Training',i)
    for j in tqdm(os.listdir(path_train)): #Instantly make your loops show a smart progress meter 
        img = cv2.imread(os.path.join(path_train,j))
#         print(img.shape)
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
    path_test = os.path.join(filename,'Testing',i)
    for j in tqdm(os.listdir(path_test)):
        img = cv2.imread(os.path.join(path_test,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 395/395 [00:02<00:00, 170.37it/s]
# 100%|██████████| 105/105 [00:00<00:00, 241.20it/s]
# 100%|██████████| 827/827 [00:05<00:00, 146.80it/s]
# 100%|██████████| 74/74 [00:00<00:00, 88.94it/s]
# 100%|██████████| 822/822 [00:05<00:00, 151.10it/s]
# 100%|██████████| 115/115 [00:00<00:00, 181.24it/s]
# 100%|██████████| 826/826 [00:05<00:00, 148.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.01it/s]

# %%
X_train = X_train/255.0

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=42)

datagen = ImageDataGenerator(
    rotation_range=15, #rotate images
    width_shift_range=0.1,
    height_shift_range=0.1, #shift image in horizontal and vertical
    zoom_range=0.1, #zoom images
    horizontal_flip=True,
    rescale = 1.0/255.0
    )

datagen2 = ImageDataGenerator(
            rescale=1.0/255.0
            )
lb = LabelEncoder()

#train and test splitting 
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.15,random_state=42,stratify=y_train)

labels_train=lb.fit(y_train)
y_train=lb.transform(y_train)
y_test=lb.transform(y_test)

# train_generator = datagen.flow(X_train, y_train, batch_size=16)
# test_generator = datagen2.flow(X_test,y_test,batch_size=1)

# %% [markdown]
# # Analyzing Data

# %%
category_mapping = dict(zip(lb.classes_, lb.transform(lb.classes_)))

print(category_mapping)
# Out:
# {'glioma_tumor': 0, 'meningioma_tumor': 1, 'no_tumor': 2, 'pituitary_tumor': 3}

# %%
print("Train")
c0=0;c1=0;c2=0;c3=0
for i in y_train:
    if i==0: c0+=1
    if i==1: c1+=1
    if i==2: c2+=1
    if i==3: c3+=1
print("c0",c0,"c1",c1,"c2",c2,"c3",c3)
print("Train")
c0=0;c1=0;c2=0;c3=0
for i in y_test:
    if i==0: c0+=1
    if i==1: c1+=1
    if i==2: c2+=1
    if i==3: c3+=1
print("c0",c0,"c1",c1,"c2",c2,"c3",c3)
# Out:
# Train
# c0 787 c1 796 c2 425 c3 766
# Train
# c0 139 c1 141 c2 75 c3 135

# %% [markdown]
# # Callback Function

# %%
early_stopping_cb=keras.callbacks.EarlyStopping(patience=9,restore_best_weights=True)

# %% [markdown]
# # Defining models

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

def vgg_model(dim):
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = VGG19(input_shape=(dim,dim,3),weights='imagenet',include_top=False)
    count = 0
    for i in base.layers:
        if "block4" in i.name:
            break
        count+=1
    a = [i.name for i in base.layers][count:]
    base.trainable = True
    set_trainable = False
    for layer in base.layers:
      if layer.name in a:
        set_trainable = True
      if set_trainable:
        layer.trainable = True
      else:
        layer.trainable = False
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(rate=0.55)(x)
    x = tf.keras.layers.Dense(128,activation='elu',kernel_initializer='GlorotNormal')(x)
    x = tf.keras.layers.Dropout(rate=0.3)(x)
#     x = Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dense(4,activation='softmax')(x)
    opt = Adam(
    learning_rate=0.000016, beta_1=0.91, beta_2=0.9994,
    epsilon=1e-08)
    model = tf.keras.Model(inputs=inp,outputs=x)
    model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def eff_model(dim=128):
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = EfficientNetB3(input_shape=(dim,dim,3),weights='imagenet',include_top=False)
    count = 0
    for i in base.layers:
        if "block6" in i.name:
            break
        count+=1
    a = [i.name for i in base.layers][count:]
    base.trainable = True
    set_trainable = False
    for layer in base.layers:
      if layer.name in a:
        set_trainable = True
      if set_trainable:
        layer.trainable = True
      else:
        layer.trainable = False
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(rate=0.55)(x)
    x = tf.keras.layers.Dense(64,activation='elu')(x)
#     x = tf.keras.layers.Dense(8,activation='relu')(x)
#     x = tf.keras.layers.Dropout(rate=0.5)(x)
#     x = tf.keras.layers.Dense(32, activation='relu')(x)
    x = tf.keras.layers.Dense(4,activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inp,outputs=x)
    opt = Adam(
        learning_rate=0.000016, beta_1=0.91, beta_2=0.9994,
        epsilon=1e-08)  
    model.compile(optimizer=opt,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    return model

# %%
def resnet_model(dim=128):
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = ResNet50(input_shape=(dim,dim,3),weights='imagenet',include_top=False)
    count = 0
    for i in base.layers:
        if "conv5_block3" in i.name:
            break
        count+=1
    a = [i.name for i in base.layers][count:]
    base.trainable = True
    set_trainable = False
    for layer in base.layers:
      if layer.name in a:
        set_trainable = True
      if set_trainable:
        layer.trainable = True
      else:
        layer.trainable = False
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(rate=0.6)(x)
    x = tf.keras.layers.Dense(64,activation='elu',kernel_initializer='GlorotNormal')(x)
#     x = tf.keras.layers.Dropout(rate=0.3)(x)
    x = Dense(64, activation='elu',kernel_initializer='GlorotNormal')(x)
    x = tf.keras.layers.Dense(4,activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inp,outputs=x)
    opt = Adam(learning_rate=0.00001)
    model.compile(optimizer=opt,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    return model

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.models import Sequential


# Modified CNN model with increased complexity and regularization
def cnn_model(dim=128):
    model = Sequential()
    model.add(Conv2D(256, (3, 3), activation='relu', input_shape=(dim, dim, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4, activation='softmax'))

#     model = Model(inputs=inp, outputs=out)
    
    opt = Adam(
        learning_rate=0.000016, beta_1=0.91, beta_2=0.9994,
        epsilon=1e-08)  
    model.compile(optimizer=opt,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    return model

# %% [markdown]
# # Training and Testing models

# %%
loss = []
Auc = []
Time = []
Auc_classes = []

# %%
Epoch = 11
batch_size = 1
K.clear_session()
with strategy.scope():
    model = vgg_model(dim=160)

# TRAIN
print('Training...')
start_time = time.time()

history=model.fit(X_train,y_train,validation_data = (X_test,y_test),epochs=Epoch,
    batch_size=32,callbacks=early_stopping_cb)
end_time = time.time()
print("Training Time: ",end_time-start_time)

# PREDICT

y_pred_proba = model.predict(X_test)
auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')  # Assumes y_test is one-hot encoded or integer-encoded
print('AUC:', auc)             

Time.append(("VGG",end_time-start_time))
Auc.append(("VGG",auc))
los, accuracy = model.evaluate(X_test, y_test)
loss.append(("VGG",los))

auc_scores = []
true_labels= y_test
for i in range(4):
    
    binary_true_labels = np.where(true_labels == i, 1, 0)
    
    predicted_probs_class = y_pred_proba[:, i]
    
    auc_class = metrics.roc_auc_score(binary_true_labels, predicted_probs_class)
    auc_scores.append(auc_class)

print("AUC scores for each class:", auc_scores)
Auc_classes.append(("VGG",auc_scores))


# PLOT TRAINING
plt.figure(figsize=(15,5))

plt.plot(np.arange(Epoch),history.history['accuracy'],'-o',label='Train accuracy',color='#808080')
plt.plot(np.arange(Epoch),history.history['val_accuracy'],'-o',label='Val accuracy',color='#000000')
x = np.argmin( history.history['val_accuracy'] ); y = np.min( history.history['val_accuracy'] )
xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
plt.scatter(x,y,s=200,color='#000000'); plt.text(x-0.03*xdist,y+0.05*ydist,'min accuracy',size=14)
plt.ylabel('accuracy',size=14)
plt.legend(loc=5)

plt2 = plt.gca().twinx()
plt2.plot(np.arange(Epoch),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
plt2.plot(np.arange(Epoch),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
ydist = plt.ylim()[1] - plt.ylim()[0]
plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
plt.ylabel('Loss',size=14)
plt.legend(loc=3)
plt.show()
# Out:
# Training...
# Epoch 1/11
# 87/87 [==============================] - 17s 131ms/step - loss: 1.5950 - accuracy: 0.4297 - val_loss: 0.7923 - val_accuracy: 0.7367
# Epoch 2/11
# 87/87 [==============================] - 11s 124ms/step - loss: 0.7448 - accuracy: 0.7004 - val_loss: 0.5456 - val_accuracy: 0.8061
# Epoch 3/11
# 87/87 [==============================] - 11s 122ms/step - loss: 0.5280 - accuracy: 0.8089 - val_loss: 0.4134 - val_accuracy: 0.8612
# Epoch 4/11
# 87/87 [==============================] - 10s 119ms/step - loss: 0.3954 - accuracy: 0.8551 - val_loss: 0.3825 - val_accuracy: 0.8776
# Epoch 5/11
# 87/87 [==============================] - 10s 120ms/step - loss: 0.3164 - accuracy: 0.8854 - val_loss: 0.3064 - val_accuracy: 0.9041
# Epoch 6/11
# 87/87 [==============================] - 10s 118ms/step - loss: 0.2315 - accuracy: 0.9268 - val_loss: 0.2594 - val_accuracy: 0.9163
# Epoch 7/11
# 87/87 [==============================] - 10s 120ms/step - loss: 0.1968 - accuracy: 0.9315 - val_loss: 0.2631 - val_accuracy: 0.9102
# Epoch 8/11
# 87/87 [==============================] - 10s 120ms/step - loss: 0.1349 - accuracy: 0.9567 - val_loss: 0.3331 - val_accuracy: 0.8878
# Epoch 9/11
# 87/87 [==============================] - 11s 123ms/step - loss: 0.1393 - accuracy: 0.9539 - val_loss: 0.2059 - val_accuracy: 0.9449
# Epoch 10/11
# 87/87 [==============================] - 10s 120ms/step - loss: 0.1036 - accuracy: 0.9654 - val_loss: 0.2322 - val_accuracy: 0.9429
# Epoch 11/11
# 87/87 [==============================] - 13s 145ms/step - loss: 0.0956 - accuracy: 0.9661 - val_loss: 0.1790 - val_accuracy: 0.9490
# Training Time:  125.3533661365509
# 16/16 [==============================] - 2s 55ms/step
# AUC: 0.9930132283213259
# 16/16 [==============================] - 1s 56ms/step - loss: 0.1790 - accuracy: 0.9490
# AUC scores for each class: [0.9829264793293571, 0.9922981568412281, 0.9979759036144578, 0.9988523735002609]

# %%
batch_size = 32
Epoch = 13
K.clear_session()
with strategy.scope():
    model = eff_model(dim=160)

# TRAIN
print('Training...')
start_time = time.time()

history=model.fit(X_train,y_train,validation_data = (X_test,y_test),epochs=Epoch,
    batch_size=batch_size,callbacks=early_stopping_cb)
end_time = time.time()
print("Training Time: ",end_time-start_time)

# PREDICT

y_pred_proba = model.predict(X_test)
auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')  # Assumes y_test is one-hot encoded or integer-encoded
print('AUC:', auc)

Time.append(("eff",end_time-start_time))
Auc.append(("eff",auc))
los, accuracy = model.evaluate(X_test, y_test)
loss.append(("eff",los))


auc_scores = []
true_labels= y_test
for i in range(4):
    
    binary_true_labels = np.where(true_labels == i, 1, 0)
    
    predicted_probs_class = y_pred_proba[:, i]
    
    auc_class = metrics.roc_auc_score(binary_true_labels, predicted_probs_class)
    auc_scores.append(auc_class)

print("AUC scores for each class:", auc_scores)
Auc_classes.append(("eff",auc_scores))

# PLOT TRAINING
plt.figure(figsize=(15,5))

plt.plot(np.arange(Epoch),history.history['accuracy'],'-o',label='Train accuracy',color='#808080')
plt.plot(np.arange(Epoch),history.history['val_accuracy'],'-o',label='Val accuracy',color='#000000')
x = np.argmin( history.history['val_accuracy'] ); y = np.min( history.history['val_accuracy'] )
xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
plt.scatter(x,y,s=200,color='#000000'); plt.text(x-0.03*xdist,y+0.05*ydist,'min accuracy',size=14)
plt.ylabel('accuracy',size=14)
plt.legend(loc=5)

plt2 = plt.gca().twinx()
plt2.plot(np.arange(Epoch),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
plt2.plot(np.arange(Epoch),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
ydist = plt.ylim()[1] - plt.ylim()[0]
plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
plt.ylabel('Loss',size=14)
plt.legend(loc=3)
plt.show()
# Out:
# Training...
# Epoch 1/13
# 2023-10-25 09:26:43.562827: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/efficientnetb3/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 87/87 [==============================] - 64s 147ms/step - loss: 1.3973 - accuracy: 0.3767 - val_loss: 1.1575 - val_accuracy: 0.4878
# Epoch 2/13
# 87/87 [==============================] - 7s 80ms/step - loss: 1.0140 - accuracy: 0.5811 - val_loss: 0.8244 - val_accuracy: 0.6878
# Epoch 3/13
# 87/87 [==============================] - 7s 83ms/step - loss: 0.7888 - accuracy: 0.6875 - val_loss: 0.6583 - val_accuracy: 0.7653
# Epoch 4/13
# 87/87 [==============================] - 7s 79ms/step - loss: 0.6833 - accuracy: 0.7368 - val_loss: 0.5684 - val_accuracy: 0.8041
# Epoch 5/13
# 87/87 [==============================] - 7s 79ms/step - loss: 0.5949 - accuracy: 0.7830 - val_loss: 0.5075 - val_accuracy: 0.8286
# Epoch 6/13
# 87/87 [==============================] - 7s 81ms/step - loss: 0.5172 - accuracy: 0.8129 - val_loss: 0.4674 - val_accuracy: 0.8286
# Epoch 7/13
# 87/87 [==============================] - 7s 79ms/step - loss: 0.4739 - accuracy: 0.8298 - val_loss: 0.4274 - val_accuracy: 0.8408
# Epoch 8/13
# 87/87 [==============================] - 7s 77ms/step - loss: 0.4304 - accuracy: 0.8468 - val_loss: 0.3927 - val_accuracy: 0.8633
# Epoch 9/13
# 87/87 [==============================] - 7s 78ms/step - loss: 0.4002 - accuracy: 0.8616 - val_loss: 0.3649 - val_accuracy: 0.8673
# Epoch 10/13
# 87/87 [==============================] - 7s 80ms/step - loss: 0.3646 - accuracy: 0.8713 - val_loss: 0.3415 - val_accuracy: 0.8755
# Epoch 11/13
# 87/87 [==============================] - 7s 76ms/step - loss: 0.3227 - accuracy: 0.8886 - val_loss: 0.3183 - val_accuracy: 0.8735
# Epoch 12/13
# 87/87 [==============================] - 7s 78ms/step - loss: 0.3291 - accuracy: 0.8810 - val_loss: 0.3016 - val_accuracy: 0.8837
# Epoch 13/13
# 87/87 [==============================] - 7s 78ms/step - loss: 0.2869 - accuracy: 0.9005 - val_loss: 0.2876 - val_accuracy: 0.8918
# Training Time:  147.71935987472534
# 16/16 [==============================] - 7s 44ms/step
# AUC: 0.9848771877170609
# 16/16 [==============================] - 1s 36ms/step - loss: 0.2876 - accuracy: 0.8918
# AUC scores for each class: [0.9792166266986412, 0.9706151313784064, 0.9933493975903613, 0.9963275952008347]

# %%
batch_size = 1
Epoch = 15
K.clear_session()
with strategy.scope():
    model = resnet_model(dim=160)

# TRAIN
print('Training...')
start_time = time.time()

history=model.fit(X_train ,y_train,validation_data = (X_test,y_test),epochs=Epoch,
    batch_size=32,callbacks=early_stopping_cb)
end_time = time.time()
print("Training Time: ",end_time-start_time)

# PREDICT

y_pred_proba = model.predict(X_test)
auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')  # Assumes y_test is one-hot encoded or integer-encoded
print('AUC:', auc)
             
Time.append(("Resnet",end_time-start_time))
Auc.append(("Resnet",auc))
los, accuracy = model.evaluate(X_test, y_test)
loss.append(("Resnet",los))

auc_scores = []
true_labels= y_test
for i in range(4):
    
    binary_true_labels = np.where(true_labels == i, 1, 0)
    
    predicted_probs_class = y_pred_proba[:, i]
    
    auc_class = metrics.roc_auc_score(binary_true_labels, predicted_probs_class)
    auc_scores.append(auc_class)

print("AUC scores for each class:", auc_scores)
Auc_classes.append(("resnet",auc_scores))


# PLOT TRAINING
plt.figure(figsize=(15,5))

plt.plot(np.arange(Epoch),history.history['accuracy'],'-o',label='Train accuracy',color='#808080')
plt.plot(np.arange(Epoch),history.history['val_accuracy'],'-o',label='Val accuracy',color='#000000')
x = np.argmin( history.history['val_accuracy'] ); y = np.min( history.history['val_accuracy'] )
xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
plt.scatter(x,y,s=200,color='#000000'); plt.text(x-0.03*xdist,y+0.05*ydist,'min accuracy',size=14)
plt.ylabel('accuracy',size=14)
plt.legend(loc=5)

plt2 = plt.gca().twinx()
plt2.plot(np.arange(Epoch),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
plt2.plot(np.arange(Epoch),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
ydist = plt.ylim()[1] - plt.ylim()[0]
plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
plt.ylabel('Loss',size=14)
plt.legend(loc=3)
plt.show()
# Out:
# Training...
# Epoch 1/15
# 87/87 [==============================] - 19s 92ms/step - loss: 1.7748 - accuracy: 0.2776 - val_loss: 1.1580 - val_accuracy: 0.5143
# Epoch 2/15
# 87/87 [==============================] - 5s 57ms/step - loss: 1.3546 - accuracy: 0.4156 - val_loss: 0.8958 - val_accuracy: 0.6469
# Epoch 3/15
# 87/87 [==============================] - 5s 56ms/step - loss: 1.0840 - accuracy: 0.5461 - val_loss: 0.7482 - val_accuracy: 0.7000
# Epoch 4/15
# 87/87 [==============================] - 5s 57ms/step - loss: 0.9284 - accuracy: 0.6265 - val_loss: 0.6381 - val_accuracy: 0.7551
# Epoch 5/15
# 87/87 [==============================] - 5s 56ms/step - loss: 0.7986 - accuracy: 0.6738 - val_loss: 0.5591 - val_accuracy: 0.7837
# Epoch 6/15
# 87/87 [==============================] - 5s 57ms/step - loss: 0.7149 - accuracy: 0.7159 - val_loss: 0.4969 - val_accuracy: 0.8102
# Epoch 7/15
# 87/87 [==============================] - 5s 57ms/step - loss: 0.6397 - accuracy: 0.7531 - val_loss: 0.4501 - val_accuracy: 0.8347
# Epoch 8/15
# 87/87 [==============================] - 5s 60ms/step - loss: 0.5800 - accuracy: 0.7801 - val_loss: 0.4206 - val_accuracy: 0.8490
# Epoch 9/15
# 87/87 [==============================] - 5s 56ms/step - loss: 0.5517 - accuracy: 0.7913 - val_loss: 0.3942 - val_accuracy: 0.8571
# Epoch 10/15
# 87/87 [==============================] - 5s 56ms/step - loss: 0.4813 - accuracy: 0.8208 - val_loss: 0.3751 - val_accuracy: 0.8714
# Epoch 11/15
# 87/87 [==============================] - 5s 56ms/step - loss: 0.4509 - accuracy: 0.8270 - val_loss: 0.3506 - val_accuracy: 0.8776
# Epoch 12/15
# 87/87 [==============================] - 5s 56ms/step - loss: 0.4225 - accuracy: 0.8479 - val_loss: 0.3372 - val_accuracy: 0.8857
# Epoch 13/15
# 87/87 [==============================] - 5s 54ms/step - loss: 0.4014 - accuracy: 0.8533 - val_loss: 0.3228 - val_accuracy: 0.8837
# Epoch 14/15
# 87/87 [==============================] - 5s 56ms/step - loss: 0.3635 - accuracy: 0.8634 - val_loss: 0.3143 - val_accuracy: 0.8918
# Epoch 15/15
# 87/87 [==============================] - 5s 58ms/step - loss: 0.3344 - accuracy: 0.8749 - val_loss: 0.3084 - val_accuracy: 0.8959
# Training Time:  88.9262797832489
# 16/16 [==============================] - 3s 38ms/step
# AUC: 0.9819436851726476
# 16/16 [==============================] - 1s 34ms/step - loss: 0.3084 - accuracy: 0.8959
# AUC scores for each class: [0.9720633749410729, 0.96514865166941, 0.9949236947791165, 0.9956390193009912]

# %%
batch_size = 1
Epoch = 19
K.clear_session()
with strategy.scope():
    model = cnn_model(dim=160)

# TRAIN
print('Training...')
start_time = time.time()

history=model.fit(X_train ,y_train,validation_data = (X_test,y_test),epochs=Epoch,
    batch_size=32,callbacks=early_stopping_cb)
end_time = time.time()
print("Training Time: ",end_time-start_time)

# PREDICT

y_pred_proba = model.predict(X_test)
auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')  # Assumes y_test is one-hot encoded or integer-encoded
print('AUC:', auc)
             
Time.append(("CNN",end_time-start_time))
Auc.append(("CNN",auc))
los, accuracy = model.evaluate(X_test, y_test)
loss.append(("CNN",los))

auc_scores = []
true_labels= y_test
for i in range(4):
    
    binary_true_labels = np.where(true_labels == i, 1, 0)
    
    predicted_probs_class = y_pred_proba[:, i]
    
    auc_class = metrics.roc_auc_score(binary_true_labels, predicted_probs_class)
    auc_scores.append(auc_class)

print("AUC scores for each class:", auc_scores)
Auc_classes.append(("CNN",auc_scores))

# PLOT TRAINING
plt.figure(figsize=(15,5))

plt.plot(np.arange(Epoch),history.history['accuracy'],'-o',label='Train accuracy',color='#808080')
plt.plot(np.arange(Epoch),history.history['val_accuracy'],'-o',label='Val accuracy',color='#000000')
x = np.argmin( history.history['val_accuracy'] ); y = np.min( history.history['val_accuracy'] )
xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
plt.scatter(x,y,s=200,color='#000000'); plt.text(x-0.03*xdist,y+0.05*ydist,'min accuracy',size=14)
plt.ylabel('accuracy',size=14)
plt.legend(loc=5)

plt2 = plt.gca().twinx()
plt2.plot(np.arange(Epoch),history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
plt2.plot(np.arange(Epoch),history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
ydist = plt.ylim()[1] - plt.ylim()[0]
plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
plt.ylabel('Loss',size=14)
plt.legend(loc=3)
plt.show()
# Out:
# Training...
# Epoch 1/19
# 87/87 [==============================] - 12s 100ms/step - loss: 4.6711 - accuracy: 0.3425 - val_loss: 1.3242 - val_accuracy: 0.3816
# Epoch 2/19
# 87/87 [==============================] - 8s 93ms/step - loss: 1.4002 - accuracy: 0.4102 - val_loss: 1.3080 - val_accuracy: 0.4531
# Epoch 3/19
# 87/87 [==============================] - 8s 94ms/step - loss: 1.2959 - accuracy: 0.4521 - val_loss: 1.2324 - val_accuracy: 0.4796
# Epoch 4/19
# 87/87 [==============================] - 8s 93ms/step - loss: 1.2266 - accuracy: 0.4546 - val_loss: 1.1555 - val_accuracy: 0.5286
# Epoch 5/19
# 87/87 [==============================] - 8s 92ms/step - loss: 1.1861 - accuracy: 0.4805 - val_loss: 1.1184 - val_accuracy: 0.5776
# Epoch 6/19
# 87/87 [==============================] - 8s 94ms/step - loss: 1.1117 - accuracy: 0.5242 - val_loss: 1.0587 - val_accuracy: 0.6041
# Epoch 7/19
# 87/87 [==============================] - 8s 94ms/step - loss: 1.0566 - accuracy: 0.5335 - val_loss: 0.9843 - val_accuracy: 0.6286
# Epoch 8/19
# 87/87 [==============================] - 8s 93ms/step - loss: 1.0319 - accuracy: 0.5584 - val_loss: 0.9529 - val_accuracy: 0.6286
# Epoch 9/19
# 87/87 [==============================] - 8s 93ms/step - loss: 0.9864 - accuracy: 0.5743 - val_loss: 0.9092 - val_accuracy: 0.6265
# Epoch 10/19
# 87/87 [==============================] - 8s 93ms/step - loss: 0.9188 - accuracy: 0.6164 - val_loss: 0.8576 - val_accuracy: 0.6510
# Epoch 11/19
# 87/87 [==============================] - 8s 94ms/step - loss: 0.8995 - accuracy: 0.6103 - val_loss: 0.8312 - val_accuracy: 0.6531
# Epoch 12/19
# 87/87 [==============================] - 8s 93ms/step - loss: 0.8673 - accuracy: 0.6229 - val_loss: 0.7967 - val_accuracy: 0.6816
# Epoch 13/19
# 87/87 [==============================] - 8s 93ms/step - loss: 0.8213 - accuracy: 0.6521 - val_loss: 0.7671 - val_accuracy: 0.6735
# Epoch 14/19
# 87/87 [==============================] - 8s 94ms/step - loss: 0.7915 - accuracy: 0.6626 - val_loss: 0.7375 - val_accuracy: 0.6755
# Epoch 15/19
# 87/87 [==============================] - 8s 94ms/step - loss: 0.7585 - accuracy: 0.6824 - val_loss: 0.6926 - val_accuracy: 0.7122
# Epoch 16/19
# 87/87 [==============================] - 8s 93ms/step - loss: 0.7244 - accuracy: 0.6994 - val_loss: 0.6589 - val_accuracy: 0.7388
# Epoch 17/19
# 87/87 [==============================] - 8s 93ms/step - loss: 0.6968 - accuracy: 0.7094 - val_loss: 0.6631 - val_accuracy: 0.7469
# Epoch 18/19
# 87/87 [==============================] - 8s 93ms/step - loss: 0.6703 - accuracy: 0.7141 - val_loss: 0.6235 - val_accuracy: 0.7367
# Epoch 19/19
# 87/87 [==============================] - 8s 93ms/step - loss: 0.6379 - accuracy: 0.7386 - val_loss: 0.6127 - val_accuracy: 0.7469
# Training Time:  158.60021018981934
# 16/16 [==============================] - 1s 33ms/step
# AUC: 0.929000943435806
# 16/16 [==============================] - 1s 31ms/step - loss: 0.6127 - accuracy: 0.7469
# AUC scores for each class: [0.8923527844391154, 0.8823995610559043, 0.952706827309237, 0.9885446009389671]

# %% [markdown]
# # Results trial 2

# %%
#Loss
plt.figure(figsize=(8, 6))
loss_names, loss_values = zip(*loss)
bars = plt.bar(loss_names, loss_values)
plt.title('Loss',fontsize=20)
plt.xlabel('Model',fontsize=12)
plt.ylabel('Value',fontsize=12)
plt.ylim(0, 5.7)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)

for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height()+0.05,
             str(round(bar.get_height(), 2)),
             ha='center',
            fontsize=12)

plt.show()

#AUC
plt.figure(figsize=(8, 6))
loss_names, loss_values = zip(*Auc)
bars = plt.bar(loss_names, loss_values)
plt.title('AUC',fontsize=20)
plt.xlabel('Model',fontsize=12)
plt.ylabel('Value',fontsize=12)
plt.ylim(0.9, 1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)

# Add values above the bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height()+0.001,
             str(round(bar.get_height(), 4)),
             ha='center',
            fontsize=12)

plt.show()

#Time
plt.figure(figsize=(8, 6))
loss_names, loss_values = zip(*Time)
bars = plt.bar(loss_names, loss_values)
plt.title('Time',fontsize=20)
plt.xlabel('Model',fontsize=12)
plt.ylabel('Value (s)',fontsize=12)
plt.ylim(80,175)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)

for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height()+1,
             str(round(bar.get_height(), 1)),
             ha='center',
            fontsize=12)

plt.show()

#AUC of each class
models, auc_scores = zip(*Auc_classes)
num_classes = len(auc_scores[0])
bar_width = 0.2
index = np.arange(num_classes)

plt.figure(figsize=(15, 6))
for i, (model, scores) in enumerate(Auc_classes):
    bars = plt.bar(index + i * bar_width, scores, bar_width, label=model)

    # Add values above the bars in the grouped bar graph
    for bar in bars:
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height()+0.001, str(round(bar.get_height(), 3)), ha='center')

# Increase font size for x-axis model names
plt.xticks(index + bar_width * (len(Auc_classes) - 1) / 2, range(num_classes), fontsize=12)
plt.xlabel('Classes')
plt.ylabel('AUC Score')
plt.title('AUC Scores by Class')
plt.legend(loc=3)
plt.ylim(0.86,1.01)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Results trial 1

# %%
#Loss
plt.figure(figsize=(8, 6))
loss_names, loss_values = zip(*loss)
bars = plt.bar(loss_names, loss_values)
plt.title('Loss',fontsize=20)
plt.xlabel('Model',fontsize=12)
plt.ylabel('Value',fontsize=12)
plt.ylim(0, 5.7)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)

for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height()+0.05,
             str(round(bar.get_height(), 2)),
             ha='center',
            fontsize=12)

plt.show()

#AUC
plt.figure(figsize=(8, 6))
loss_names, loss_values = zip(*Auc)
bars = plt.bar(loss_names, loss_values)
plt.title('AUC',fontsize=20)
plt.xlabel('Model',fontsize=12)
plt.ylabel('Value',fontsize=12)
plt.ylim(0.9, 1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)

# Add values above the bars
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height()+0.001,
             str(round(bar.get_height(), 4)),
             ha='center',
            fontsize=12)

plt.show()

#Time
plt.figure(figsize=(8, 6))
loss_names, loss_values = zip(*Time)
bars = plt.bar(loss_names, loss_values)
plt.title('Time',fontsize=20)
plt.xlabel('Model',fontsize=12)
plt.ylabel('Value (s)',fontsize=12)
plt.ylim(80,175)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)

for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height()+1,
             str(round(bar.get_height(), 1)),
             ha='center',
            fontsize=12)

plt.show()

#AUC of each class
models, auc_scores = zip(*Auc_classes)
num_classes = len(auc_scores[0])
bar_width = 0.2
index = np.arange(num_classes)

plt.figure(figsize=(15, 6))
for i, (model, scores) in enumerate(Auc_classes):
    bars = plt.bar(index + i * bar_width, scores, bar_width, label=model)

    # Add values above the bars in the grouped bar graph
    for bar in bars:
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height()+0.001, str(round(bar.get_height(), 3)), ha='center')

# Increase font size for x-axis model names
plt.xticks(index + bar_width * (len(Auc_classes) - 1) / 2, range(num_classes), fontsize=12)
plt.xlabel('Classes')
plt.ylabel('AUC Score')
plt.title('AUC Scores by Class')
plt.legend(loc=3)
plt.ylim(0.86,1.01)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Highlights

# %%
# Conclusion: Transfer learning model give better results in less training time.

# Matrix used: AUC since dataset is imbalanced

# Models used: ResNet50, EfficientNetB6, VGG19(Best Result), CNN

# About Dataset: 
#     Dataset used contains MRI scan of brain of multiple peoples.  
#     Brain Tumors are classified as: Benign Tumor, Malignant Tumor, Pituitary Tumor.

# Dataset: 
#     Train: 
#       'glioma_tumor': 787
#      'meningioma_tumor': 796
#      'no_tumor': 425
#      'pituitary_tumor': 766
#     Test: 
#       'glioma_tumor': 139
#      'meningioma_tumor': 141
#      'no_tumor': 75
#      'pituitary_tumor': 135

#Label Encoding:
#     'glioma_tumor': 0
#      'meningioma_tumor': 1
#      'no_tumor': 2
#      'pituitary_tumor': 3

# Train Data augmentation: 
# NO augmentation was done on data due to lose of AUC score after image augmentation

# Loss fn and optimiser:
# optimiser = Adam(
#         learning_rate=0.000016,
#         beta_1=0.91, 
#         beta_2=0.9994,
#         epsilon=1e-08
#         )
# loss= sparse_categorical_crossentropy

# Hardware Used: GPU T4x2
